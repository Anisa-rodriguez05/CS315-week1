# %% [markdown]
# # Tutorial 1: Working with Files in Python
#
# This tutorial can be found in this link [Working with Files in Python](https://realpython.com/working-with-files-in-python/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.
#
# by: Anisa Rodriguez

# %% [markdown]
# ## 1. `with ... open as` pattern

# %%
with open('data.txt', 'w') as f:
    data = 'some data to be written to the file'
    f.write(data)

# %% [markdown]
# ## 2. `Getting a Directory Listing` pattern

# %%
import os
entries = os.listdir('my_directory/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 entries = os.listdir('my_directory/')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_directory/'

# %%
entries = os.listdir('my_directory/')
for entry in entries:
    print(entry)

# %% [markdown]
# ## 2. `Directory Listing in Modern Python Versions` pattern

# %%
#os.scandir() returns an iterator as opposed to a list when called:
import os
entries = os.scandir('my_directory/')
entries
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 entries = os.scandir('my_directory/')
#       3 entries
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_directory/'

# %%
#The ScandirIterator points to all the entries in the current directory. You can loop over the contents of the iterator and print out the filenames:
import os

with os.scandir('my_directory/') as entries:
    for entry in entries:
        print(entry.name)

# %%
#Another way to get a directory 
#listing is to use the pathlib module: 
from pathlib import Path

entries = Path('my_directory/')
for entry in entries.iterdir():
    print(entry.name)

# %% [markdown]
# ## 2. `Listing All Files in a Directory` pattern

# %% [markdown]
# ## 6. Listing Subdirectories

# %%
import os

# List all subdirectories using os.listdir
basepath = 'my_directory/'
for entry in os.listdir(basepath):
    if os.path.isdir(os.path.join(basepath, entry)):
        print(entry)

# %%
from pathlib import Path

# List all subdirectory using pathlib
basepath = Path('my_directory/')
for entry in basepath.iterdir():
    if entry.is_dir():
        print(entry.name)

# %% [markdown]
# ## 7 Getting File Attributes

# %%
import os
with os.scandir('my_directory/') as dir_contents:
    for entry in dir_contents:
        info = entry.stat()
        print(info.st_mtime)

# %%
from datetime import datetime
from os import scandir

def convert_date(timestamp):
    d = datetime.utcfromtimestamp(timestamp)
    formated_date = d.strftime('%d %b %Y')
    return formated_date

def get_files():
    dir_entries = scandir('my_directory/')
    for entry in dir_entries:
        if entry.is_file():
            info = entry.stat()
            print(f'{entry.name}\t Last Modified: {convert_date(info.st_mtime)}')

# %% [markdown]
# ## Creating a Single Directory

# %%
import os

os.mkdir('example_directory/')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 import os
#       2
# ----> 3 os.mkdir('example_directory/')
#
# FileExistsError: [Errno 17] File exists: 'example_directory/'

# %%
from pathlib import Path

p = Path('example_directory/')
p.mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 4
#       1 from pathlib import Path
#       2
#       3 p = Path('example_directory/')
# ----> 4 p.mkdir()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: 'example_directory'

# %%
from pathlib import Path

p = Path('example_directory/')
p.mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[14], line 4
#       1 from pathlib import Path
#       2
#       3 p = Path('example_directory/')
# ----> 4 p.mkdir()
#       5
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: 'example_directory'

# %%
from pathlib import Path

p = Path('example_directory')
try:
    p.mkdir()
except FileExistsError as exc:
    print(exc)
# Out:
# [Errno 17] File exists: 'example_directory'

# %%
from pathlib import Path

p = Path('example_directory')
p.mkdir(exist_ok=True)

# %% [markdown]
# ## 9 creating multiple directories

# %%
import os


os.makedirs('2018/10/05')

# %%
import pathlib

p = pathlib.Path('2018/10/05')
p.mkdir(parents=True)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[21], line 4
#       1 import pathlib
#       2
#       3 p = pathlib.Path('2018/10/05')
# ----> 4 p.mkdir(parents=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: '2018/10/05'

# %%
import os

os.makedirs('2018/10/05', mode=0o770)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 import os
#       2
# ----> 3 os.makedirs('2018/10/05', mode=0o770)
#
# File <frozen os>:232, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '2018/10/05'

# %% [markdown]
# ## Filename Pattern Matching

# %%
import os

# Get .txt files
for f_name in os.listdir('some_directory'):
    if f_name.endswith('.txt'):
        print(f_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os
#       2
#       3 # Get .txt files
# ----> 4 for f_name in os.listdir('some_directory'):
#       5     if f_name.endswith('.txt'):
#       6         print(f_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'some_directory'

# %% [markdown]
# ## Using String Methods

# %%
import os

# Get .txt files
for f_name in os.listdir('some_directory'):
    if f_name.endswith('.txt'):
        print(f_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import os
#       2
#       3 # Get .txt files
# ----> 4 for f_name in os.listdir('some_directory'):
#       5     if f_name.endswith('.txt'):
#       6         print(f_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'some_directory'

# %% [markdown]
# ## Simple Filename Pattern Matching Using fnmatch

# %%
import os
import fnmatch

for file_name in os.listdir('some_directory/'):
    if fnmatch.fnmatch(file_name, '*.txt'):
        print(file_name)

# %% [markdown]
# ## More Advanced Pattern Matching

# %%
for filename in os.listdir('.'):
    if fnmatch.fnmatch(filename, 'data_*_backup.txt'):
        print(filename)

# %% [markdown]
# ## Filename Pattern Matching Using glob

# %%
import glob
glob.glob('*.py')
# Out:
# []

# %%
import glob
for name in glob.glob('*[0-9]*.txt'):
    print(name)

# %%
import glob
for file in glob.iglob('**/*.py', recursive=True):
    print(file)

# %%
from pathlib import Path
p = Path('.')
for name in p.glob('*.p*'):
    print(name)

# %% [markdown]
# ## Traversing Directories and Processing Files

# %%
# Walking a directory tree and printing the names of the directories and files
for dirpath, dirnames, files in os.walk('.'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: .
# tutorial_1.ipynb
# data.txt
# Found directory: ./2018
# Found directory: ./2018/10
# Found directory: ./2018/10/05
# Found directory: ./example_directory

# %% [markdown]
# ## Traversing Directories and Processing Files

# %%
# Walking a directory tree and printing the names of the directories and files
for dirpath, dirnames, files in os.walk('.'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: .
# tutorial_1.ipynb
# data.txt
# Found directory: ./2018
# Found directory: ./2018/10
# Found directory: ./2018/10/05
# Found directory: ./example_directory

# %%
for dirpath, dirnames, files in os.walk('.', topdown=False):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./2018/10/05
# Found directory: ./2018/10
# Found directory: ./2018
# Found directory: ./example_directory
# Found directory: .
# tutorial_1.ipynb
# data.txt

# %% [markdown]
# ## Making Temporary Files and Directories

# %%
from tempfile import TemporaryFile

# Create a temporary file and write some data to it
fp = TemporaryFile('w+t')
fp.write('Hello universe!')

# Go back to the beginning and read data from file
fp.seek(0)
data = fp.read()

# Close the file, after which it will be removed
fp.close()

# %%
with TemporaryFile('w+t') as fp:
    fp.write('Hello universe!')
    fp.seek(0)
    fp.read()
# File is now closed and removed

# %%
import tempfile
with tempfile.TemporaryDirectory() as tmpdir:
    print('Created temporary directory ', tmpdir)
    os.path.exists(tmpdir)




# Directory contents have been removed

tmpdir

os.path.exists(tmpdir)
# Out:
# Created temporary directory  /var/folders/s3/5kzl1x7j3mvc3nq02k37z2000000gn/T/tmpvtaleb35
# False

# %% [markdown]
# ## Deleting Files and Directories

# %%
import os

data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
os.remove(data_file)

# %%
import os

data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
os.unlink(data_file)

# %%
import os

data_file = 'home/data.txt'

# If the file exists, delete it
if os.path.isfile(data_file):
    os.remove(data_file)
else:
    print(f'Error: {data_file} not a valid filename')
# Out:
# Error: home/data.txt not a valid filename

# %%
import os

data_file = 'home/data.txt'

# Use exception handling
try:
    os.remove(data_file)
except OSError as e:
    print(f'Error: {data_file} : {e.strerror}')

# %%
import os

data_file = 'home/data.txt'

# Use exception handling
try:
    os.remove(data_file)
except OSError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# Error: home/data.txt : No such file or directory

# %%
import os

data_file = 'home/data.txt'

# Use exception handling
try:
    os.remove(data_file)
except OSError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# Error: home/data.txt : No such file or directory

# %%
from pathlib import Path

data_file = Path('home/data.txt')

try:
    data_file.unlink()
except IsADirectoryError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 7
#       3 data_file = Path('home/data.txt')
#       4
#       5 try:
#       6     data_file.unlink()
# ----> 7 except IsADirectoryError as e:
#       8     print(f'Error: {data_file} : {e.strerror}')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:746, in Path.unlink(self, missing_ok)
#     741 """
#     742 Remove this file or link.
#     743 If the path is a directory, use rmdir() instead.
#     744 """
#     745 try:
# --> 746     os.unlink(self)
#     747 except FileNotFoundError:
#     748     if not missing_ok:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home/data.txt'

# %% [markdown]
# ## Deleting Directories

# %%
import os

trash_dir = 'my_documents/bad_dir'

try:
    os.rmdir(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
from pathlib import Path

trash_dir = Path('my_documents/bad_dir')

try:
    trash_dir.rmdir()
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')

# %% [markdown]
# ## Deleting Entire Directory Trees

# %%
import shutil

trash_dir = 'my_documents/bad_dir'

try:
    shutil.rmtree(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
import os

for dirpath, dirnames, files in os.walk('.', topdown=False):
    try:
        os.rmdir(dirpath)
    except OSError as ex:
        pass

# %% [markdown]
# ## Copying, Moving, and Renaming Files and Directories

# %%
import shutil

src = 'path/to/file.txt'
dst = 'path/to/dest_dir'
shutil.copy(src, dst)

# %%
import shutil

src = 'path/to/file.txt'
dst = 'path/to/dest_dir'
shutil.copy2(src, dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 5
#       1 import shutil
#       2
#       3 src = 'path/to/file.txt'
#       4 dst = 'path/to/dest_dir'
# ----> 5 shutil.copy2(src, dst)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/shutil.py:468, in copy2(src, dst, follow_symlinks)
#     465         else:
#     466             raise
# --> 468 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     469 copystat(src, dst, follow_symlinks=follow_symlinks)
#     470 return dst
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/file.txt'

# %% [markdown]
# ## Copying Directories

# %%
import shutil
shutil.copytree('data_1', 'data1_backup')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 import shutil
# ----> 2 shutil.copytree('data_1', 'data1_backup')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/shutil.py:591, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     552 """Recursively copy a directory tree and return the destination directory.
#     553
#     554 If exception(s) occur, an Error is raised with a list of reasons.
#    (...)    588 `src` tree.
#     589 """
#     590 sys.audit("shutil.copytree", src, dst)
# --> 591 with os.scandir(src) as itr:
#     592     entries = list(itr)
#     593 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     594                  ignore=ignore, copy_function=copy_function,
#     595                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     596                  dirs_exist_ok=dirs_exist_ok)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_1'

# %% [markdown]
# ## Moving Files and Directories

# %%
import shutil
shutil.move('dir_1/', 'backup/')

# %% [markdown]
# ## Renaming Files and Directories

# %%
os.rename('first.zip', 'first_01.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 os.rename('first.zip', 'first_01.zip')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'first.zip' -> 'first_01.zip'

# %% [markdown]
# ## Reading ZIP Files

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
# Out:
#   Cell In[25], line 3
#     with zipfile.ZipFile('data.zip', 'r') as zipobj:
#                                                     ^
# _IncompleteInputError: incomplete input

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
    zipobj.namelist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 import zipfile
#       2
# ----> 3 with zipfile.ZipFile('data.zip', 'r') as zipobj:
#       4     zipobj.namelist()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.zip'

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
    bar_info = zipobj.getinfo('sub_dir/bar.py')
    bar_info.file_size
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 import zipfile
#       2
# ----> 3 with zipfile.ZipFile('data.zip', 'r') as zipobj:
#       4     bar_info = zipobj.getinfo('sub_dir/bar.py')
#       5     bar_info.file_size
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.zip'

# %% [markdown]
# ## Extracting ZIP Archives

# %%
import zipfile
import os

os.listdir('.')


data_zip = zipfile.ZipFile('data.zip', 'r')

# Extract a single file to current directory
data_zip.extract('file1.py')


os.listdir('.')


# Extract all files into a different directory
data_zip.extractall(path='extract_dir/')

os.listdir('.')


os.listdir('extract_dir')


data_zip.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 7
#       3
#       4 os.listdir('.')
#       5
#       6
# ----> 7 data_zip = zipfile.ZipFile('data.zip', 'r')
#       8
#       9 # Extract a single file to current directory
#      10 data_zip.extract('file1.py')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.zip'

# %% [markdown]
# ## Extracting Data From Password Protected Archives

# %%
import zipfile
import os

os.listdir('.')


data_zip = zipfile.ZipFile('data.zip', 'r')

# Extract a single file to current directory
data_zip.extract('file1.py')


os.listdir('.')


# Extract all files into a different directory
data_zip.extractall(path='extract_dir/')

os.listdir('.')


os.listdir('extract_dir')


data_zip.close()

# %% [markdown]
# ## Creating New ZIP Archives

# %%
import zipfile

file_list = ['file1.py', 'sub_dir/', 'sub_dir/bar.py', 'sub_dir/foo.py']
with zipfile.ZipFile('new.zip', 'w') as new_zip:
    for name in file_list:
        new_zip.write(name)

# %% [markdown]
# ## Opening TAR Archives

# %%
import tarfile

with tarfile.open('example.tar', 'r') as tar_file:
    print(tar_file.getnames())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 import tarfile
#       2
# ----> 3 with tarfile.open('example.tar', 'r') as tar_file:
#       4     print(tar_file.getnames())
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/tarfile.py:1858, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1856     saved_pos = fileobj.tell()
#    1857 try:
# -> 1858     return func(name, "r", fileobj, **kwargs)
#    1859 except (ReadError, CompressionError) as e:
#    1860     error_msgs.append(f'- method {comptype}: {e!r}')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/tarfile.py:1926, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1923     raise CompressionError("gzip module is not available") from None
#    1925 try:
# -> 1926     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1927 except OSError as e:
#    1928     if fileobj is not None and mode == 'r':
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/gzip.py:203, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     201 try:
#     202     if fileobj is None:
# --> 203         fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     204     if filename is None:
#     205         filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.tar'

# %%
for entry in tar.getmembers():
    print(entry.name)
    print(' Modified:', time.ctime(entry.mtime))
    print(' Size    :', entry.size, 'bytes')
    print()

# %% [markdown]
# ## Reading Multiple Files

# %%
import fileinput
for line in fileinput.input()
    process(line)

# %%
# File: fileinput-example.py
import fileinput
import sys

files = fileinput.input()
for line in files:
    if fileinput.isfirstline():
        print(f'\n--- Reading {fileinput.filename()} ---')
    print(' -> ' + line, end='')
print()
